# %%
import nfl_data_py as nfl
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import urllib.request
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from adjustText import adjust_text

# %%
team_color = {'ARI':'#97233F','ATL':'#A71930','BAL':'#241773','BUF':'#00338D','CAR':'#0085CA','CHI':'#00143F',
          'CIN':'#FB4F14','CLE':'#FB4F14','DAL':'#B0B7BC','DEN':'#002244','DET':'#046EB4','GB':'#24423C',
          'HOU':'#C9243F','IND':'#003D79','JAX':'#136677','KC':'#CA2430','LAR':'#002147','LAC':'#2072BA',
          'MIA':'#0091A0','MIN':'#4F2E84','NE':'#0A2342','NO':'#A08A58','NYG':'#192E6C','NYJ':'#203731',
          'LV':'#C4C9CC','PHI':'#014A53','PIT':'#FFC20E','SEA':'#7AC142','SF':'#C9243F','TB':'#D40909',
          'TEN':'#4095D1','WAS':'#FFC20F'}

# %%
import_data = nfl.import_seasonal_data([2022])             
rb_season_data = pd.DataFrame(index = import_data.index)
rb_season_data["Player ID"] = import_data["player_id"]
rb_season_data["Carries"] = import_data["carries"]
rb_season_data["Rushing Yards"] = import_data["rushing_yards"]
rb_season_data["Rushing TDs"] = import_data["rushing_tds"]
rb_season_data["Fumbles"] = import_data["rushing_fumbles"]
rb_season_data["Fumbles Lost"] = import_data["rushing_fumbles_lost"]
rb_season_data["Rushing 1st Downs"] = import_data["rushing_first_downs"]
rb_season_data["Rushing EPA"] = import_data["rushing_epa"]
rb_season_data["Rushing 2Pt Conversions"] = import_data["rushing_2pt_conversions"]
rb_season_data["Games Played"] = import_data["games"]
rb_season_data
# Out:
#       Player ID  Carries  Rushing Yards  Rushing TDs  Fumbles  Fumbles Lost  \
# 0    00-0019596        6           -4.0            0      1.0           1.0
# 1    00-0023459        7            8.0            0      1.0           1.0
# 2    00-0026143        7           16.0            0      2.0           1.0
# 3    00-0026158        3            6.0            0      0.0           0.0
# 4    00-0026498        4            4.0            0      0.0           0.0
# ..          ...      ...            ...          ...      ...           ...
# 400  00-0038120       21          112.0            0      0.0           0.0
# 401  00-0038124        1            7.0            0      0.0           0.0
# 402  00-0038128        4           16.0            0      1.0           1.0
# 403  00-0038129        0            0.0            0      0.0           0.0
# 404  00-0038134        7           29.0            0      0.0           0.0
#
#      Rushing 1st Downs  Rushing EPA  Rushing 2Pt Conversions  Games Played
# 0                  0.0    -8.552574                        0             3
# 1                  1.0    -8.631042                        0             3
# 2                  3.0    -2.707272                        0             3
# 3                  1.0    -0.136921                        0             3
# 4                  2.0    -1.428848                        0             3
# ..                 ...          ...                      ...           ...
# 400                4.0     0.976767                        0             3
# 401                0.0     0.470464                        0             2
# 402                1.0    -5.589098                        0             1
# 403                0.0     0.000000                        0             1
# 404                2.0    -1.979646                        0             2
#
# [405 rows x 10 columns]

# %%
import_weekly_data = nfl.import_weekly_data([2022])             
rb_data = pd.DataFrame(index = import_weekly_data.index)
rb_data["Player"] = import_weekly_data["player_name"]
rb_data["Player ID"] = import_weekly_data["player_id"]
rb_data["Team"] = import_weekly_data["recent_team"]
rb_data["Player Full Name"] = import_weekly_data["player_display_name"]
rb_data = rb_data.drop_duplicates(subset=['Player Full Name'])
rb_data.loc[rb_data["Team"] == "LA", "Team"] = "LAR"
# Out:
# Downcasting floats.

# %%
rb_merged_season_data = rb_data.merge(rb_season_data, left_on='Player ID', right_on='Player ID')
#rb_merged_season_data = rb_merged_season_data.loc[rb_merged_season_data["Attempts"] > 20, :]
rb_merged_season_data = rb_merged_season_data.drop(columns=["Player ID"])
rb_merged_season_data.sort_values(by=['Team'])
# Out:
#           Player Team Player Full Name  Carries  Rushing Yards  Rushing TDs  \
# 220     G.Dortch  ARI      Greg Dortch        0            0.0            0
# 20        Z.Ertz  ARI        Zach Ertz        0            0.0            0
# 294   E.Benjamin  ARI     Eno Benjamin       17           75.0            0
# 237      M.Brown  ARI   Marquise Brown        0            0.0            0
# 253  A.Baccellia  ARI  Andre Baccellia        0            0.0            0
# ..           ...  ...              ...      ...            ...          ...
# 385     J.Dotson  WAS     Jahan Dotson        1          -10.0            0
# 74    J.McKissic  WAS    J.D. McKissic        9           25.0            0
# 82       C.Wentz  WAS     Carson Wentz       11           57.0            0
# 236   T.McLaurin  WAS   Terry McLaurin        1            7.0            0
# 324      D.Milne  WAS        Dax Milne        0            0.0            0
#
#      Fumbles  Fumbles Lost  Rushing 1st Downs  Rushing EPA  \
# 220      0.0           0.0                0.0     0.000000
# 20       0.0           0.0                0.0     0.000000
# 294      0.0           0.0                4.0     0.967854
# 237      0.0           0.0                0.0     0.000000
# 253      0.0           0.0                0.0     0.000000
# ..       ...           ...                ...          ...
# 385      0.0           0.0                0.0    -1.455014
# 74       0.0           0.0                2.0    -2.982321
# 82       0.0           0.0                2.0     4.518738
# 236      0.0           0.0                1.0     2.577441
# 324      0.0           0.0                0.0     0.000000
#
#      Rushing 2Pt Conversions  Games Played
# 220                        0             3
# 20                         0             3
# 294                        0             3
# 237                        0             3
# 253                        0             2
# ..                       ...           ...
# 385                        0             3
# 74                         0             3
# 82                         0             3
# 236                        0             3
# 324                        0             3
#
# [405 rows x 12 columns]

# %%
rb_data_ngs = pd.read_csv("../Resources/ngs_2022_rushing.csv")
rb_data_ngs = rb_data_ngs.loc[rb_data_ngs["week"] == 0, :]
rb_data_ngs = rb_data_ngs.sort_values(by=['team_abbr'])
rb_data_ngs = rb_data_ngs.drop_duplicates(subset=['player_display_name'])
rb_data_full = rb_data_ngs.merge(rb_merged_season_data, left_on='player_display_name', right_on='Player Full Name')
rb_data_full = rb_data_full.drop(columns = ["season", "season_type", "player_first_name", "player_last_name",
                                            "player_jersey_number", "Player Full Name", "Team", "Carries",
                                           "Rushing Yards", "Rushing TDs", "week"])
rb_data_full.columns
# Out:
# Index(['player_display_name', 'player_position', 'team_abbr', 'efficiency',
#        'percent_attempts_gte_eight_defenders', 'avg_time_to_los',
#        'rush_attempts', 'rush_yards', 'expected_rush_yards',
#        'rush_yards_over_expected', 'avg_rush_yards',
#        'rush_yards_over_expected_per_att', 'rush_pct_over_expected',
#        'rush_touchdowns', 'player_gsis_id', 'player_short_name', 'Player',
#        'Fumbles', 'Fumbles Lost', 'Rushing 1st Downs', 'Rushing EPA',
#        'Rushing 2Pt Conversions', 'Games Played'],
#       dtype='object')

# %%
rb_data_full
# Out:
#       player_display_name player_position team_abbr  efficiency  \
# 0            James Conner              RB       ARI    5.151222
# 1   Cordarrelle Patterson              RB       ATL    3.197616
# 2        Devin Singletary              RB       BUF    3.986000
# 3     Christian McCaffrey              RB       CAR    3.286790
# 4          Khalil Herbert              RB       CHI    2.470583
# 5        David Montgomery              RB       CHI    3.777925
# 6               Joe Mixon              RB       CIN    5.131472
# 7             Kareem Hunt              RB       CLE    4.007483
# 8              Nick Chubb              RB       CLE    3.702053
# 9            Tony Pollard              RB       DAL    3.559295
# 10        Ezekiel Elliott              RB       DAL    3.834663
# 11       Javonte Williams              RB       DEN    3.876705
# 12          Melvin Gordon              RB       DEN    4.178550
# 13          D'Andre Swift              RB       DET    2.571905
# 14        Jamaal Williams              RB       DET    3.702202
# 15            Aaron Jones              RB        GB    3.078295
# 16            A.J. Dillon              RB        GB    4.082826
# 17          Dameon Pierce              RB       HOU    4.044780
# 18        Jonathan Taylor              RB       IND    3.259336
# 19         Travis Etienne              RB       JAX    4.257946
# 20         James Robinson              RB       JAX    3.411870
# 21  Clyde Edwards-Helaire              RB        KC    3.270259
# 22          Austin Ekeler              RB       LAC    6.276875
# 23      Darrell Henderson              RB       LAR    3.535495
# 24              Cam Akers              RB       LAR    5.008952
# 25            Josh Jacobs              RB        LV    3.514479
# 26         Raheem Mostert              RB       MIA    5.617179
# 27          Chase Edmonds              RB       MIA    4.479620
# 28            Dalvin Cook              RB       MIN    3.777094
# 29    Rhamondre Stevenson              RB        NE    3.690138
# 30          Damien Harris              RB        NE    3.304688
# 31           Alvin Kamara              RB        NO    4.090900
# 32         Saquon Barkley              RB       NYG    2.951167
# 33            Breece Hall              RB       NYJ    3.883036
# 34         Michael Carter              RB       NYJ    3.842869
# 35          Miles Sanders              RB       PHI    3.299685
# 36           Najee Harris              RB       PIT    4.776797
# 37          Rashaad Penny              RB       SEA    3.758794
# 38         Jeffery Wilson              RB        SF    3.747072
# 39      Leonard Fournette              RB        TB    4.029780
# 40          Derrick Henry              RB       TEN    4.665312
# 41         Antonio Gibson              RB       WAS    4.572339
#
#     percent_attempts_gte_eight_defenders  avg_time_to_los  rush_attempts  \
# 0                               6.666667         2.563296             30
# 1                              14.285714         2.831792             49
# 2                              17.391304         2.881263             23
# 3                              16.000000         2.676766             50
# 4                              18.181818         2.615774             33
# 5                              22.857143         2.969219             35
# 6                              17.241379         2.778143             58
# 7                              41.666667         3.046235             36
# 8                              37.096774         3.171895             62
# 9                              28.571429         2.873154             28
# 10                             25.000000         2.842763             40
# 11                             18.918919         3.067829             37
# 12                             20.588235         2.715724             34
# 13                              3.703704         2.766148             27
# 14                             23.255814         2.761575             43
# 15                              0.000000         2.747429             32
# 16                              5.000000         2.644649             40
# 17                             10.869565         3.000600             46
# 18                              8.196721         2.840982             61
# 19                              7.692308         2.840895             26
# 20                             13.725490         2.833600             51
# 21                             13.636364         2.930400             22
# 22                             15.625000         2.937857             32
# 23                              0.000000         2.876654             27
# 24                             10.000000         3.037125             30
# 25                             23.809524         2.720750             42
# 26                              4.166667         2.928100             24
# 27                             13.043478         2.466000             23
# 28                             16.279070         2.926872             43
# 29                             10.344828         2.806148             29
# 30                             25.714286         2.507853             35
# 31                             16.666667         3.137524             24
# 32                             18.867925         2.726957             53
# 33                             14.285714         2.658444             21
# 34                             14.285714         2.722000             28
# 35                             17.777778         2.847150             45
# 36                             27.500000         2.777973             40
# 37                             15.625000         2.874333             32
# 38                             10.256410         2.853086             39
# 39                             17.543860         3.124113             57
# 40                             35.185185         2.862234             54
# 41                             22.500000         2.562829             40
#
#     rush_yards  expected_rush_yards  rush_yards_over_expected  ...  \
# 0           90           123.513384                -33.513384  ...
# 1          302           224.923275                 73.076725  ...
# 2           80            85.711870                 -5.711870  ...
# 3          243           235.943920                  4.056080  ...
# 4          240           141.709875                 93.290125  ...
# 5          159           129.449699                 29.550301  ...
# 6          163           203.638047                -48.638047  ...
# 7          151           133.294007                 17.705993  ...
# 8          341           237.031578                103.968422  ...
# 9          156            95.471640                 60.528360  ...
# 10         178           185.787882                -15.787882  ...
# 11         176           170.424120                  5.575880  ...
# 12         131           129.641701                 -6.641701  ...
# 13         231           153.668834                 77.331166  ...
# 14         168           163.338913                  2.661087  ...
# 15         217           136.286294                 75.713706  ...
# 16         138           147.735553                -13.735553  ...
# 17         182           178.405306                  3.594694  ...
# 18         286           263.499427                 21.500573  ...
# 19         112            92.943734                 13.056266  ...
# 20         230           208.847933                 20.152067  ...
# 21         116            68.766763                 -5.766763  ...
# 22          80           106.221361                -24.221361  ...
# 23         111           105.751220                  2.248780  ...
# 24         105           113.153297                 -8.153297  ...
# 25         192           165.143671                 21.856329  ...
# 26          78            91.175791                -13.175791  ...
# 27          79           122.344287                -43.344287  ...
# 28         203           209.531500                 -6.531500  ...
# 29         145           141.936891                 -0.936891  ...
# 30         160           151.187953                  8.812047  ...
# 31         100           117.714730                -17.714730  ...
# 32         317           200.526243                112.473757  ...
# 33         112            81.721688                 30.278312  ...
# 34         122           129.081370                -16.081370  ...
# 35         222           186.287635                  8.712365  ...
# 36         128           173.749842                -45.749842  ...
# 37         141           127.717293                  9.282707  ...
# 38         181           137.769918                 43.230082  ...
# 39         227           218.095430                  8.904570  ...
# 40         192           233.000407                -43.000407  ...
# 41         124           126.318557                 -2.318557  ...
#
#     rush_touchdowns  player_gsis_id  player_short_name             Player  \
# 0                 1      00-0033553           J.Conner           J.Conner
# 1                 2      00-0030578        C.Patterson        C.Patterson
# 2                 0      00-0035250       D.Singletary       D.Singletary
# 3                 1      00-0033280        C.McCaffrey        C.McCaffrey
# 4                 3      00-0036906          K.Herbert          K.Herbert
# 5                 0      00-0035685       D.Montgomery       D.Montgomery
# 6                 0      00-0033897            J.Mixon            J.Mixon
# 7                 1      00-0033923             K.Hunt             K.Hunt
# 8                 4      00-0034791            N.Chubb            N.Chubb
# 9                 1      00-0035261          T.Pollard          T.Pollard
# 10                1      00-0033045          E.Elliott          E.Elliott
# 11                0      00-0036997         J.Williams         J.Williams
# 12                1      00-0032144           M.Gordon           M.Gordon
# 13                1      00-0036275            D.Swift            D.Swift
# 14                4      00-0033948         J.Williams         J.Williams
# 15                1      00-0033293            A.Jones            A.Jones
# 16                1      00-0036265           A.Dillon           A.Dillon
# 17                1      00-0037258           D.Pierce           D.Pierce
# 18                1      00-0036223           J.Taylor           J.Taylor
# 19                0      00-0036973          T.Etienne          T.Etienne
# 20                3      00-0035831         J.Robinson         J.Robinson
# 21                1      00-0036360  C.Edwards-Helaire  C.Edwards-Helaire
# 22                0      00-0033699           A.Ekeler           A.Ekeler
# 23                1      00-0035664        D.Henderson        D.Henderson
# 24                1      00-0036414            C.Akers            C.Akers
# 25                0      00-0035700           J.Jacobs           J.Jacobs
# 26                0      00-0031687          R.Mostert          R.Mostert
# 27                2      00-0034681          C.Edmonds          C.Edmonds
# 28                1      00-0033893             D.Cook             D.Cook
# 29                1      00-0036875        R.Stevenson        R.Stevenson
# 30                2      00-0035657           D.Harris           D.Harris
# 31                0      00-0033906           A.Kamara           A.Kamara
# 32                2      00-0034844          S.Barkley          S.Barkley
# 33                0      00-0038120             B.Hall             B.Hall
# 34                0      00-0036924           M.Carter           M.Carter
# 35                1      00-0035243          M.Sanders          M.Sanders
# 36                1      00-0036893           N.Harris           N.Harris
# 37                0      00-0034750            R.Penny            R.Penny
# 38                0      00-0034115           J.Wilson           J.Wilson
# 39                0      00-0033856        L.Fournette        L.Fournette
# 40                2      00-0032764            D.Henry            D.Henry
# 41                2      00-0036328           A.Gibson           A.Gibson
#
#    Fumbles Fumbles Lost Rushing 1st Downs  Rushing EPA  \
# 0      1.0          0.0              11.0     1.844458
# 1      0.0          0.0              17.0     5.707311
# 2      0.0          0.0               4.0    -3.393813
# 3      0.0          0.0              13.0     4.858590
# 4      0.0          0.0              12.0    10.451192
# 5      0.0          0.0               6.0    -5.515701
# 6      0.0          0.0               6.0   -13.309987
# 7      0.0          0.0              10.0     1.211997
# 8      0.0          0.0              15.0    12.104826
# 9      0.0          0.0               8.0    -0.412419
# 10     0.0          0.0              10.0     2.503639
# 11     1.0          1.0               7.0    -5.520829
# 12     2.0          1.0               6.0    -9.066493
# 13     0.0          0.0               6.0     9.344993
# 14     0.0          0.0              11.0    -1.461840
# 15     0.0          0.0              11.0     6.992100
# 16     0.0          0.0              11.0    -6.345146
# 17     2.0          0.0              13.0    -3.554035
# 18     0.0          0.0              15.0    -2.495635
# 19     0.0          0.0               6.0    -2.622044
# 20     0.0          0.0              12.0    -3.251622
# 21     0.0          0.0               3.0     1.391296
# 22     0.0          0.0               4.0   -13.047282
# 23     0.0          0.0               6.0     3.691532
# 24     1.0          1.0               5.0    -7.876255
# 25     1.0          0.0               9.0     1.430239
# 26     0.0          0.0               5.0    -3.704798
# 27     0.0          0.0               4.0    -2.438864
# 28     1.0          1.0              13.0    -3.629641
# 29     0.0          0.0               9.0     3.374718
# 30     0.0          0.0               9.0     1.376709
# 31     1.0          1.0               4.0   -11.378240
# 32     1.0          0.0              12.0     0.816032
# 33     0.0          0.0               4.0     0.976767
# 34     0.0          0.0               4.0    -1.598847
# 35     0.0          0.0              11.0     3.642896
# 36     0.0          0.0               8.0    -3.193853
# 37     1.0          0.0               7.0     2.521919
# 38     0.0          0.0               7.0    -2.119233
# 39     0.0          0.0               8.0   -12.619515
# 40     1.0          0.0               7.0    -9.627454
# 41     0.0          0.0               9.0    -6.178179
#
#     Rushing 2Pt Conversions  Games Played
# 0                         0             3
# 1                         0             3
# 2                         0             3
# 3                         0             3
# 4                         0             3
# 5                         0             3
# 6                         0             3
# 7                         0             3
# 8                         0             3
# 9                         0             3
# 10                        0             3
# 11                        0             3
# 12                        0             3
# 13                        0             3
# 14                        0             3
# 15                        0             3
# 16                        0             3
# 17                        0             3
# 18                        0             3
# 19                        0             3
# 20                        0             3
# 21                        0             3
# 22                        0             3
# 23                        0             3
# 24                        0             3
# 25                        0             3
# 26                        0             3
# 27                        0             3
# 28                        0             3
# 29                        0             3
# 30                        0             3
# 31                        0             2
# 32                        0             3
# 33                        0             3
# 34                        0             3
# 35                        0             3
# 36                        0             3
# 37                        0             3
# 38                        0             3
# 39                        0             3
# 40                        0             3
# 41                        0             3
#
# [42 rows x 23 columns]

# %%
rb_graph = rb_data_full[["player_short_name", "percent_attempts_gte_eight_defenders", "efficiency", "team_abbr",
                         "rush_attempts"]]

x = rb_graph["percent_attempts_gte_eight_defenders"]
y = rb_graph["efficiency"]
color = []
x_mean = [np.mean(x)]*len(x)
y_mean = [np.mean(y)]*len(y)

for team in rb_graph["team_abbr"]:
    color.append(team_color[team])

size = rb_graph["rush_attempts"].to_numpy()
s = [s*2 for s in size]

#Create a figure with size 12x12
fig, ax = plt.subplots(figsize=(12,12))

#Make a scatter plot with success rate data
plt.scatter(x, y, c = color, s = s)

mean_line = ax.plot(x_mean,y, c = 'grey')
mean_line = ax.plot(x,y_mean, c = 'grey')
    
#Add a grid
ax.grid(zorder=0,alpha=.4)
ax.set_axisbelow(True)

#Adding labels and text
plt.xlabel('% of Eight man boxes', fontsize=18, fontweight = "bold")
plt.ylabel('Efficiency (The lower the number, the more a north/south runner)', fontsize=18, fontweight = "bold")
plt.yscale('log')
plt.title('Percent of Eight Man boxes vs Efficiency 2022 through Week 3', fontsize=18, fontweight = "bold")
plt.xticks(fontsize=14, fontweight = "bold")
plt.yticks(fontsize=14, fontweight = "bold")

#Add player names to points
texts = [plt.text(x[i], y[i], txt, ha='center', va='center') for i, txt in enumerate(rb_graph["player_short_name"])]    
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='red'))

#plt.savefig('Images/AvgAirYards1stDown_vs_Passing1stDown', dpi=400)
plt.show()

# %%
rb_graph = rb_data_full[["player_short_name", "percent_attempts_gte_eight_defenders", "rush_pct_over_expected",
                         "team_abbr", "rush_attempts"]]

x = rb_graph["percent_attempts_gte_eight_defenders"]
y = rb_graph["rush_pct_over_expected"]
color = []
x_mean = [np.mean(x)]*len(x)
y_mean = [np.mean(y)]*len(y)

for team in rb_graph["team_abbr"]:
    color.append(team_color[team])

size = rb_graph["rush_attempts"].to_numpy()
s = [s*2 for s in size]

#Create a figure with size 12x12
fig, ax = plt.subplots(figsize=(12,12))

#Make a scatter plot with success rate data
plt.scatter(x, y, c = color, s = s)

mean_line = ax.plot(x_mean,y, c = 'grey')
mean_line = ax.plot(x,y_mean, c = 'grey')
    
#Add a grid
ax.grid(zorder=0,alpha=.4)
ax.set_axisbelow(True)

#Adding labels and text
plt.xlabel('% of Eight man boxes', fontsize=18, fontweight = "bold")
plt.ylabel('Rush % over Expected', fontsize=18, fontweight = "bold")
#plt.yscale('log')
plt.title('Percent of Eight Man boxes vs Rush % over Expected 2022 through Week 3', fontsize=18, fontweight = "bold")
plt.xticks(fontsize=14, fontweight = "bold")
plt.yticks(fontsize=14, fontweight = "bold")

#Add player names to points
texts = [plt.text(x[i], y[i], txt, ha='center', va='center') for i, txt in enumerate(rb_graph["player_short_name"])]    
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='red'))

#plt.savefig('Images/AvgAirYards1stDown_vs_Passing1stDown', dpi=400)
plt.show()

# %%
rb_graph = rb_data_full[["player_short_name", "percent_attempts_gte_eight_defenders", "Rushing EPA",
                         "team_abbr", "rush_attempts"]]

x = rb_graph["percent_attempts_gte_eight_defenders"]
y = rb_graph["Rushing EPA"]
color = []
x_mean = [np.mean(x)]*len(x)
y_mean = [np.mean(y)]*len(y)

for team in rb_graph["team_abbr"]:
    color.append(team_color[team])

size = rb_graph["rush_attempts"].to_numpy()
s = [s*2 for s in size]

#Create a figure with size 12x12
fig, ax = plt.subplots(figsize=(12,12))

#Make a scatter plot with success rate data
plt.scatter(x, y, c = color, s = s)

mean_line = ax.plot(x_mean,y, c = 'grey')
mean_line = ax.plot(x,y_mean, c = 'grey')
    
#Add a grid
ax.grid(zorder=0,alpha=.4)
ax.set_axisbelow(True)

#Adding labels and text
plt.xlabel('% of Eight man boxes', fontsize=18, fontweight = "bold")
plt.ylabel('Rush EPA', fontsize=18, fontweight = "bold")
#plt.yscale('log')
plt.title('Percent of Eight Man boxes vs Rush EPA 2022 through Week 3', fontsize=18, fontweight = "bold")
plt.xticks(fontsize=14, fontweight = "bold")
plt.yticks(fontsize=14, fontweight = "bold")

#Add player names to points
texts = [plt.text(x[i], y[i], txt, ha='center', va='center') for i, txt in enumerate(rb_graph["player_short_name"])]    
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='red'))

plt.savefig('Images/Per8Man_vs_RushEPA', dpi=400)
plt.show()

# %%
rb_data_pfr = pd.read_csv("../Resources/advstats_season_rush.csv")
rb_data_pfr = rb_data_pfr.loc[rb_data_pfr["season"] == 2022, :]
rb_data_pfr = rb_data_pfr.drop(columns=["season", "tm", "pfr_id", "age", "pos", "gs", "att", "yds",
                                       "x1d", "loaded"])
rb_data_pfr.loc[rb_data_pfr["player"] == "AJ Dillon", "player"] = "A.J. Dillon"
rb_data_pfr.loc[rb_data_pfr["player"] == "Jeff Wilson", "player"] = "Jeffery Wilson"
rb_data_all = rb_data_full.merge(rb_data_pfr, left_on='player_display_name', right_on='player')
rb_data_all.columns
# Out:
# Index(['player_display_name', 'player_position', 'team_abbr', 'efficiency',
#        'percent_attempts_gte_eight_defenders', 'avg_time_to_los',
#        'rush_attempts', 'rush_yards', 'expected_rush_yards',
#        'rush_yards_over_expected', 'avg_rush_yards',
#        'rush_yards_over_expected_per_att', 'rush_pct_over_expected',
#        'rush_touchdowns', 'player_gsis_id', 'player_short_name', 'Player',
#        'Fumbles', 'Fumbles Lost', 'Rushing 1st Downs', 'Rushing EPA',
#        'Rushing 2Pt Conversions', 'Games Played', 'player', 'g', 'ybc',
#        'ybc_att', 'yac', 'yac_att', 'brk_tkl', 'att_br'],
#       dtype='object')

# %%
rb_data_all
# Out:
#       player_display_name player_position team_abbr  efficiency  \
# 0            James Conner              RB       ARI    5.151222
# 1   Cordarrelle Patterson              RB       ATL    3.197616
# 2        Devin Singletary              RB       BUF    3.986000
# 3     Christian McCaffrey              RB       CAR    3.286790
# 4          Khalil Herbert              RB       CHI    2.470583
# 5        David Montgomery              RB       CHI    3.777925
# 6               Joe Mixon              RB       CIN    5.131472
# 7             Kareem Hunt              RB       CLE    4.007483
# 8              Nick Chubb              RB       CLE    3.702053
# 9            Tony Pollard              RB       DAL    3.559295
# 10        Ezekiel Elliott              RB       DAL    3.834663
# 11       Javonte Williams              RB       DEN    3.876705
# 12          Melvin Gordon              RB       DEN    4.178550
# 13          D'Andre Swift              RB       DET    2.571905
# 14        Jamaal Williams              RB       DET    3.702202
# 15            Aaron Jones              RB        GB    3.078295
# 16            A.J. Dillon              RB        GB    4.082826
# 17          Dameon Pierce              RB       HOU    4.044780
# 18        Jonathan Taylor              RB       IND    3.259336
# 19         Travis Etienne              RB       JAX    4.257946
# 20         James Robinson              RB       JAX    3.411870
# 21  Clyde Edwards-Helaire              RB        KC    3.270259
# 22          Austin Ekeler              RB       LAC    6.276875
# 23      Darrell Henderson              RB       LAR    3.535495
# 24              Cam Akers              RB       LAR    5.008952
# 25            Josh Jacobs              RB        LV    3.514479
# 26         Raheem Mostert              RB       MIA    5.617179
# 27          Chase Edmonds              RB       MIA    4.479620
# 28            Dalvin Cook              RB       MIN    3.777094
# 29    Rhamondre Stevenson              RB        NE    3.690138
# 30          Damien Harris              RB        NE    3.304688
# 31           Alvin Kamara              RB        NO    4.090900
# 32         Saquon Barkley              RB       NYG    2.951167
# 33            Breece Hall              RB       NYJ    3.883036
# 34         Michael Carter              RB       NYJ    3.842869
# 35          Miles Sanders              RB       PHI    3.299685
# 36           Najee Harris              RB       PIT    4.776797
# 37          Rashaad Penny              RB       SEA    3.758794
# 38         Jeffery Wilson              RB        SF    3.747072
# 39      Leonard Fournette              RB        TB    4.029780
# 40          Derrick Henry              RB       TEN    4.665312
# 41         Antonio Gibson              RB       WAS    4.572339
#
#     percent_attempts_gte_eight_defenders  avg_time_to_los  rush_attempts  \
# 0                               6.666667         2.563296             30
# 1                              14.285714         2.831792             49
# 2                              17.391304         2.881263             23
# 3                              16.000000         2.676766             50
# 4                              18.181818         2.615774             33
# 5                              22.857143         2.969219             35
# 6                              17.241379         2.778143             58
# 7                              41.666667         3.046235             36
# 8                              37.096774         3.171895             62
# 9                              28.571429         2.873154             28
# 10                             25.000000         2.842763             40
# 11                             18.918919         3.067829             37
# 12                             20.588235         2.715724             34
# 13                              3.703704         2.766148             27
# 14                             23.255814         2.761575             43
# 15                              0.000000         2.747429             32
# 16                              5.000000         2.644649             40
# 17                             10.869565         3.000600             46
# 18                              8.196721         2.840982             61
# 19                              7.692308         2.840895             26
# 20                             13.725490         2.833600             51
# 21                             13.636364         2.930400             22
# 22                             15.625000         2.937857             32
# 23                              0.000000         2.876654             27
# 24                             10.000000         3.037125             30
# 25                             23.809524         2.720750             42
# 26                              4.166667         2.928100             24
# 27                             13.043478         2.466000             23
# 28                             16.279070         2.926872             43
# 29                             10.344828         2.806148             29
# 30                             25.714286         2.507853             35
# 31                             16.666667         3.137524             24
# 32                             18.867925         2.726957             53
# 33                             14.285714         2.658444             21
# 34                             14.285714         2.722000             28
# 35                             17.777778         2.847150             45
# 36                             27.500000         2.777973             40
# 37                             15.625000         2.874333             32
# 38                             10.256410         2.853086             39
# 39                             17.543860         3.124113             57
# 40                             35.185185         2.862234             54
# 41                             22.500000         2.562829             40
#
#     rush_yards  expected_rush_yards  rush_yards_over_expected  ...  \
# 0           90           123.513384                -33.513384  ...
# 1          302           224.923275                 73.076725  ...
# 2           80            85.711870                 -5.711870  ...
# 3          243           235.943920                  4.056080  ...
# 4          240           141.709875                 93.290125  ...
# 5          159           129.449699                 29.550301  ...
# 6          163           203.638047                -48.638047  ...
# 7          151           133.294007                 17.705993  ...
# 8          341           237.031578                103.968422  ...
# 9          156            95.471640                 60.528360  ...
# 10         178           185.787882                -15.787882  ...
# 11         176           170.424120                  5.575880  ...
# 12         131           129.641701                 -6.641701  ...
# 13         231           153.668834                 77.331166  ...
# 14         168           163.338913                  2.661087  ...
# 15         217           136.286294                 75.713706  ...
# 16         138           147.735553                -13.735553  ...
# 17         182           178.405306                  3.594694  ...
# 18         286           263.499427                 21.500573  ...
# 19         112            92.943734                 13.056266  ...
# 20         230           208.847933                 20.152067  ...
# 21         116            68.766763                 -5.766763  ...
# 22          80           106.221361                -24.221361  ...
# 23         111           105.751220                  2.248780  ...
# 24         105           113.153297                 -8.153297  ...
# 25         192           165.143671                 21.856329  ...
# 26          78            91.175791                -13.175791  ...
# 27          79           122.344287                -43.344287  ...
# 28         203           209.531500                 -6.531500  ...
# 29         145           141.936891                 -0.936891  ...
# 30         160           151.187953                  8.812047  ...
# 31         100           117.714730                -17.714730  ...
# 32         317           200.526243                112.473757  ...
# 33         112            81.721688                 30.278312  ...
# 34         122           129.081370                -16.081370  ...
# 35         222           186.287635                  8.712365  ...
# 36         128           173.749842                -45.749842  ...
# 37         141           127.717293                  9.282707  ...
# 38         181           137.769918                 43.230082  ...
# 39         227           218.095430                  8.904570  ...
# 40         192           233.000407                -43.000407  ...
# 41         124           126.318557                 -2.318557  ...
#
#     Rushing 2Pt Conversions  Games Played                 player  g  ybc  \
# 0                         0             3           James Conner  3   51
# 1                         0             3  Cordarrelle Patterson  3  188
# 2                         0             3       Devin Singletary  3   47
# 3                         0             3    Christian McCaffrey  3  129
# 4                         0             3         Khalil Herbert  3  139
# 5                         0             3       David Montgomery  3   61
# 6                         0             3              Joe Mixon  3  119
# 7                         0             3            Kareem Hunt  3   88
# 8                         0             3             Nick Chubb  3  182
# 9                         0             3           Tony Pollard  3  133
# 10                        0             3        Ezekiel Elliott  3  136
# 11                        0             3       Javonte Williams  3   92
# 12                        0             3          Melvin Gordon  3   50
# 13                        0             3          D'Andre Swift  3  148
# 14                        0             3        Jamaal Williams  3  112
# 15                        0             3            Aaron Jones  3   82
# 16                        0             3            A.J. Dillon  3   63
# 17                        0             3          Dameon Pierce  3   71
# 18                        0             3        Jonathan Taylor  3  199
# 19                        0             3         Travis Etienne  3   75
# 20                        0             3         James Robinson  3  156
# 21                        0             3  Clyde Edwards-Helaire  3   26
# 22                        0             3          Austin Ekeler  3   37
# 23                        0             3      Darrell Henderson  3   78
# 24                        0             3              Cam Akers  3   52
# 25                        0             3            Josh Jacobs  3   82
# 26                        0             3         Raheem Mostert  3   41
# 27                        0             3          Chase Edmonds  3   49
# 28                        0             3            Dalvin Cook  3  126
# 29                        0             3    Rhamondre Stevenson  3   77
# 30                        0             3          Damien Harris  3   85
# 31                        0             2           Alvin Kamara  2   51
# 32                        0             3         Saquon Barkley  3  163
# 33                        0             3            Breece Hall  3   83
# 34                        0             3         Michael Carter  3   95
# 35                        0             3          Miles Sanders  3  112
# 36                        0             3           Najee Harris  3   83
# 37                        0             3          Rashaad Penny  3   64
# 38                        0             3         Jeffery Wilson  3  136
# 39                        0             3      Leonard Fournette  3  129
# 40                        0             3          Derrick Henry  3   66
# 41                        0             3         Antonio Gibson  3   70
#
#    ybc_att  yac  yac_att  brk_tkl  att_br
# 0      1.7   39      1.3        1    30.0
# 1      3.8  114      2.3        0     NaN
# 2      2.0   33      1.4        1    23.0
# 3      2.6  114      2.3        1    50.0
# 4      4.2  101      3.1        5     6.6
# 5      1.7   98      2.8        8     4.4
# 6      2.1   44      0.8        2    29.0
# 7      2.4   63      1.8        2    18.0
# 8      2.9  159      2.6        8     7.8
# 9      4.8   23      0.8        0     NaN
# 10     3.4   42      1.1        0     NaN
# 11     2.5   84      2.3        6     6.2
# 12     1.5   81      2.4        4     8.5
# 13     5.5   83      3.1        2    13.5
# 14     2.6   56      1.3        1    43.0
# 15     2.6  135      4.2        2    16.0
# 16     1.6   75      1.9        3    13.3
# 17     1.5  111      2.4        6     7.7
# 18     3.3   87      1.4        8     7.6
# 19     2.9   37      1.4        0     NaN
# 20     3.1   74      1.5        3    17.0
# 21     1.2   90      4.1        1    22.0
# 22     1.2   43      1.3        0     NaN
# 23     2.9   33      1.2        0     NaN
# 24     1.7   53      1.8        0     NaN
# 25     2.0  110      2.6        6     7.0
# 26     1.7   37      1.5        3     8.0
# 27     2.1   30      1.3        0     NaN
# 28     2.9   77      1.8        4    10.8
# 29     2.7   68      2.3        4     7.3
# 30     2.4   75      2.1        4     8.8
# 31     2.1   49      2.0        2    12.0
# 32     3.1  154      2.9        0     NaN
# 33     4.0   29      1.4        1    21.0
# 34     3.4   27      1.0        4     7.0
# 35     2.5  110      2.4        3    15.0
# 36     2.1   45      1.1        2    20.0
# 37     2.0   77      2.4        2    16.0
# 38     3.5   45      1.2        1    39.0
# 39     2.3   98      1.7        3    19.0
# 40     1.2  126      2.3        6     9.0
# 41     1.8   54      1.4        2    20.0
#
# [42 rows x 31 columns]

# %%
rb_graph = rb_data_all[["player_short_name", "ybc_att", "yac_att", "team_abbr", "rush_attempts"]]

x = rb_graph["ybc_att"]
y = rb_graph["yac_att"]
color = []
x_mean = [np.mean(x)]*len(x)
y_mean = [np.mean(y)]*len(y)

for team in rb_graph["team_abbr"]:
    color.append(team_color[team])

size = rb_graph["rush_attempts"].to_numpy()
s = [s*2 for s in size]

#Create a figure with size 12x12
fig, ax = plt.subplots(figsize=(12,12))

#Make a scatter plot with success rate data
plt.scatter(x, y, c = color, s = s)

mean_line = ax.plot(x_mean,y, c = 'grey')
mean_line = ax.plot(x,y_mean, c = 'grey')
    
#Add a grid
ax.grid(zorder=0,alpha=.4)
ax.set_axisbelow(True)

#Adding labels and text
plt.xlabel('Yards Before Contact per Attempt', fontsize=18, fontweight = "bold")
plt.ylabel('Yards After Contact per Attempt', fontsize=18, fontweight = "bold")
#plt.yscale('log')
plt.title('Yards Before Contact/Att vs Yards After Contact/Att 2022 through Week 3', fontsize=18, fontweight = "bold")
plt.xticks(fontsize=14, fontweight = "bold")
plt.yticks(fontsize=14, fontweight = "bold")

#Add player names to points
texts = [plt.text(x[i], y[i], txt, ha='center', va='center') for i, txt in enumerate(rb_graph["player_short_name"])]    
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='red'))

plt.savefig('Images/AvgYBC_vs_AvgYAC', dpi=400)
plt.show()
